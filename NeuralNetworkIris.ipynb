# %% [markdown]
# <a href="https://colab.research.google.com/github/nirudi98/IrisClusteringNN/blob/master/NeuralNetworkIris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Neural Network implementation with google colab
#Iris.csv is added to files and loaded
#This code is used to cluster Iris data


#importing necessary packages

import numpy as np
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns


# Assign the csv data to a DataFrame
iris_data = pd.read_csv("/content/sample_data/Iris (1).csv")


# defining class labels (3 classes)
labels = ["Iris-sentosa","Iris-versicolor","Iris-virginica"]


# Print the first 10 instances
print("first 10 instances of Iris : \n", iris_data.head(10).style)

# skipping a blank row
print("\n")


# prnit Information of the dataset
print("dataset information : \n", iris_data.info())

# skipping a blank row
print("\n")


# Dimensions of the dataset
print("dimensions of the dataset : ", iris_data.shape)

# skipping a blank row
print("\n")


# Encoding labels using hot encoding approch - this appraoch makes it easy to read the output data
# using a function and returning the encoded target
def target_hotencoding(target):
    encoded_target = pd.DataFrame()
    for label in target.unique():
        encoded_target[label] = np.where(target == label, 1, 0)
    return encoded_target



#input data and the target
X=iris_data.iloc[0:,1:5]
y=iris_data.iloc[0:,5] 


# normalize the train data attributes
normalized_X = preprocessing.normalize(X)
print("normalized X : \n", normalized_X)


#hot encode of the output - sending the output labels into hthe encoding function
target = target_hotencoding(y)
#print(y)



#---------------------------------------------------------------------------------------#
                        
                             #implementing neural network


print("----------------------------------------------------------------- \n")
print("Neural Network Implementation \n ")


#generating weights randomly - since 3 hidden layer neurons and 4 input nodes (4,3) matrix
np.random.seed(5)
W = np.random.rand(4,3)


#generating bias randomly - since 3 hidden layer neurons (3,1) matrix
bias = np.random.rand(3,1)


#learning rate - learning rate value should be between 0 - 1 
lr = 0.05

# normalize the randomly generated weights
weights = preprocessing.normalize(W)


#printing the random weights
#print("randomly generated weights \n",weights)
#print("randomly generated bias \n",bias)
#print("SHAPE OF weights :", normalized_weights.shape)



#weighted sum of hidden layer node or output layer node
#activation function to get the output (sigmoid)

# activation function
def sigmoid(x):
    return 1/(1+np.exp(-x))

# finding the deriviative of the value returning from sigmoid function
def sigmoid_der(x):
    return x*(1-x)


# feed forward and backpropagration part 
# R=500 loop 

for iteration in range(500):
    inputs = normalized_X

   # feedforward step 1 - calculating the weighted sum 
    XW = (np.dot(normalized_X, weights)+ (bias.T))
    # + (bias.T)
    

   # feedforward step 2 - passing the weighted output to sigmiod function and assigning the returned value to z
    z = sigmoid(XW)

   # converting returned output to a matrix of zero and then representing the maximum value using 1   
    output = np.zeros_like(z)
    output[np.arange(len(z)), z.argmax(1)] = 1


   # Casting float values to int
    output = output.astype(int)
    
   #print(output)

   # calculating the mean squared error and printing MSE for each iteration
    MSE = np.mean(np.square(output - target))
    print("iteration ", iteration, "MSE : \n", )
    print(MSE)
    
   # skipping line
    print("\n")
   # output is my predicted value / target is the observed or given value
   # backpropagation step 1 (differentiating MSE using chain rule - constants are ignored)
    error_of_output = (output - target)


   # applying chain rule of differentiation
   # dcost :derivation of cost function with respect to weight
   # dcost_dpred : derivation of cost function with respect to sigmoid function
    

   # backpropagation step 2
    dcost_dpred = error_of_output

    dpred_dz = sigmoid_der(z)

    z_delta = dcost_dpred * dpred_dz

   # inputs_weights = normalized_X
   # directly multiplying the transpose of input matrix with corresponding z_delta
    inputs = normalized_X.T
    
   # multiplying by lr to increase the speed of convergence
    weights = weights - (lr * np.dot(inputs, z_delta))
    

   # normalizing the updated weights
    weights = preprocessing.normalize(weights)

   
   # updating the bias
   #dl_wrt_b1 = np.sum(z_delta, axis=0)
   #bias = bias - (lr*dl_wrt_b1)


   # end of the loop

print("\n")

#---------------------------------------------------------------------------------------#
                        
                             #displaying the output of the CNN - clusters


print("----------------------------------------------------------------- \n")
print("Final Prediction of Neural Network \n ")


# calculating the final prediction using final updated weights and inputs and sending to sigmoid
final_prediction  = sigmoid(np.dot(normalized_X, weights))

# converting the final output to zeros matrix and replacing the maximum amount with 1
prediction = np.zeros_like(final_prediction)
prediction[np.arange(len(final_prediction)), final_prediction.argmax(1)] = 1
prediction = prediction.astype(int)

# adding the final prediction to a dataframe - columns are labels
prediction = pd.DataFrame(prediction, columns=labels)

# printing clustered value using a for looping, looping through the dataframe
print("Clustered values : ")

for cluster in prediction.columns: 
   print("\t",cluster , ":", prediction[cluster].sum())


print("\n")

# plotting the final prediction in a graph 
# plt.plot(prediction)
# plt.show()
print("\n")

#---------------------------------------------------------------------------------------#
                        
                             #purity clustering section of the code
print("----------------------------------------------------------------- \n")
print("Purity Clustering of the Final Prediction of Neural Network \n ")

# importing necessary packages

import numpy as np
from sklearn import metrics

# function to compute the purity score
def purity_score(y_true, y_pred):

    # compute contingency matrix (also called confusion matrix)
    contingency_matrix = metrics.cluster.contingency_matrix(y_true, y_pred)

    print(contingency_matrix)

    #finding the max of every row in the matrix
    max_contigencyMatrix = np.amax(contingency_matrix,axis=0)

    #sum of all max values
    sum_max_contigencyMatrix = np.sum(max_contigencyMatrix)

    #total number of data points in the matrix
    tot_dataPoints = np.sum(contingency_matrix) 

    # return purity 
    return sum_max_contigencyMatrix/tot_dataPoints


# calling the purity score function by passing the target and prediction values - purity_score function
# printing purity score
print("purity score of CNN Iris clustering : " ,purity_score(target,prediction))
# Out:
# first 10 instances of Iris :
#  <pandas.io.formats.style.Styler object at 0x7f3950e31110>
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# dataset information :
#  None
#
#
# dimensions of the dataset :  (150, 6)
#
#
# normalized X :
#  [[0.80377277 0.55160877 0.22064351 0.0315205 ]
#  [0.82813287 0.50702013 0.23660939 0.03380134]
#  [0.80533308 0.54831188 0.2227517  0.03426949]
#  [0.80003025 0.53915082 0.26087943 0.03478392]
#  [0.790965   0.5694948  0.2214702  0.0316386 ]
#  [0.78417499 0.5663486  0.2468699  0.05808704]
#  [0.78010936 0.57660257 0.23742459 0.0508767 ]
#  [0.80218492 0.54548574 0.24065548 0.0320874 ]
#  [0.80642366 0.5315065  0.25658935 0.03665562]
#  [0.81803119 0.51752994 0.25041771 0.01669451]
#  [0.80373519 0.55070744 0.22325977 0.02976797]
#  [0.786991   0.55745196 0.26233033 0.03279129]
#  [0.82307218 0.51442011 0.24006272 0.01714734]
#  [0.8025126  0.55989251 0.20529392 0.01866308]
#  [0.81120865 0.55945424 0.16783627 0.02797271]
#  [0.77381111 0.59732787 0.2036345  0.05430253]
#  [0.79428944 0.57365349 0.19121783 0.05883625]
#  [0.80327412 0.55126656 0.22050662 0.04725142]
#  [0.8068282  0.53788547 0.24063297 0.04246464]
#  [0.77964883 0.58091482 0.22930848 0.0458617 ]
#  [0.8173379  0.51462016 0.25731008 0.03027177]
#  [0.78591858 0.57017622 0.23115252 0.06164067]
#  [0.77577075 0.60712493 0.16864581 0.03372916]
#  [0.80597792 0.52151512 0.26865931 0.07901744]
#  [0.776114   0.54974742 0.30721179 0.03233808]
#  [0.82647451 0.4958847  0.26447184 0.03305898]
#  [0.79778206 0.5424918  0.25529026 0.06382256]
#  [0.80641965 0.54278246 0.23262105 0.03101614]
#  [0.81609427 0.5336001  0.21971769 0.03138824]
#  [0.79524064 0.54144043 0.27072022 0.03384003]
#  [0.80846584 0.52213419 0.26948861 0.03368608]
#  [0.82225028 0.51771314 0.22840286 0.06090743]
#  [0.76578311 0.60379053 0.22089897 0.0147266 ]
#  [0.77867447 0.59462414 0.19820805 0.02831544]
#  [0.81803119 0.51752994 0.25041771 0.01669451]
#  [0.82512295 0.52807869 0.19802951 0.03300492]
#  [0.82699754 0.52627116 0.19547215 0.03007264]
#  [0.81803119 0.51752994 0.25041771 0.01669451]
#  [0.80212413 0.54690282 0.23699122 0.03646019]
#  [0.80779568 0.53853046 0.23758697 0.03167826]
#  [0.80033301 0.56023311 0.20808658 0.04801998]
#  [0.86093857 0.44003527 0.24871559 0.0573959 ]
#  [0.78609038 0.57170209 0.23225397 0.03573138]
#  [0.78889479 0.55222635 0.25244633 0.09466737]
#  [0.76693897 0.57144472 0.28572236 0.06015208]
#  [0.82210585 0.51381615 0.23978087 0.05138162]
#  [0.77729093 0.57915795 0.24385598 0.030482  ]
#  [0.79594782 0.55370283 0.24224499 0.03460643]
#  [0.79837025 0.55735281 0.22595384 0.03012718]
#  [0.81228363 0.5361072  0.22743942 0.03249135]
#  [0.76701103 0.35063361 0.51499312 0.15340221]
#  [0.74549757 0.37274878 0.52417798 0.17472599]
#  [0.75519285 0.33928954 0.53629637 0.16417236]
#  [0.75384916 0.31524601 0.54825394 0.17818253]
#  [0.7581754  0.32659863 0.5365549  0.17496355]
#  [0.72232962 0.35482858 0.57026022 0.16474184]
#  [0.72634846 0.38046824 0.54187901 0.18446945]
#  [0.75916547 0.37183615 0.51127471 0.15493173]
#  [0.76301853 0.33526572 0.53180079 0.15029153]
#  [0.72460233 0.37623583 0.54345175 0.19508524]
#  [0.76923077 0.30769231 0.53846154 0.15384615]
#  [0.73923462 0.37588201 0.52623481 0.187941  ]
#  [0.78892752 0.28927343 0.52595168 0.13148792]
#  [0.73081412 0.34743622 0.56308629 0.16772783]
#  [0.75911707 0.3931142  0.48800383 0.17622361]
#  [0.76945444 0.35601624 0.50531337 0.16078153]
#  [0.70631892 0.37838513 0.5675777  0.18919257]
#  [0.75676497 0.35228714 0.53495455 0.13047672]
#  [0.76444238 0.27125375 0.55483721 0.18494574]
#  [0.76185188 0.34011245 0.53057542 0.14964948]
#  [0.6985796  0.37889063 0.56833595 0.21312598]
#  [0.77011854 0.35349703 0.50499576 0.16412362]
#  [0.74143307 0.29421947 0.57667016 0.17653168]
#  [0.73659895 0.33811099 0.56754345 0.14490471]
#  [0.76741698 0.34773582 0.51560829 0.15588157]
#  [0.76785726 0.34902603 0.51190484 0.16287881]
#  [0.76467269 0.31486523 0.53976896 0.15743261]
#  [0.74088576 0.33173989 0.55289982 0.18798594]
#  [0.73350949 0.35452959 0.55013212 0.18337737]
#  [0.78667474 0.35883409 0.48304589 0.13801311]
#  [0.76521855 0.33391355 0.52869645 0.15304371]
#  [0.77242925 0.33706004 0.51963422 0.14044168]
#  [0.76434981 0.35581802 0.51395936 0.15814134]
#  [0.70779525 0.31850786 0.60162596 0.1887454 ]
#  [0.69333409 0.38518561 0.57777841 0.1925928 ]
#  [0.71524936 0.40530797 0.53643702 0.19073316]
#  [0.75457341 0.34913098 0.52932761 0.16893434]
#  [0.77530021 0.28304611 0.54147951 0.15998258]
#  [0.72992443 0.39103094 0.53440896 0.16944674]
#  [0.74714194 0.33960997 0.54337595 0.17659719]
#  [0.72337118 0.34195729 0.57869695 0.15782644]
#  [0.73260391 0.36029701 0.55245541 0.1681386 ]
#  [0.76262994 0.34186859 0.52595168 0.1577855 ]
#  [0.76986879 0.35413965 0.5081134  0.15397376]
#  [0.73544284 0.35458851 0.55158213 0.1707278 ]
#  [0.73239618 0.38547167 0.53966034 0.15418867]
#  [0.73446047 0.37367287 0.5411814  0.16750853]
#  [0.75728103 0.3542121  0.52521104 0.15878473]
#  [0.78258054 0.38361791 0.4603415  0.16879188]
#  [0.7431482  0.36505526 0.5345452  0.16948994]
#  [0.65387747 0.34250725 0.62274045 0.25947519]
#  [0.69052512 0.32145135 0.60718588 0.22620651]
#  [0.71491405 0.30207636 0.59408351 0.21145345]
#  [0.69276796 0.31889319 0.61579374 0.1979337 ]
#  [0.68619022 0.31670318 0.61229281 0.232249  ]
#  [0.70953708 0.28008043 0.61617694 0.1960563 ]
#  [0.67054118 0.34211284 0.61580312 0.23263673]
#  [0.71366557 0.28351098 0.61590317 0.17597233]
#  [0.71414125 0.26647062 0.61821183 0.19185884]
#  [0.69198788 0.34599394 0.58626751 0.24027357]
#  [0.71562645 0.3523084  0.56149152 0.22019275]
#  [0.71576546 0.30196356 0.59274328 0.21249287]
#  [0.71718148 0.31640359 0.58007326 0.22148252]
#  [0.6925518  0.30375079 0.60750157 0.24300063]
#  [0.67767924 0.32715549 0.59589036 0.28041899]
#  [0.69589887 0.34794944 0.57629125 0.25008866]
#  [0.70610474 0.3258945  0.59747324 0.1955367 ]
#  [0.69299099 0.34199555 0.60299216 0.19799743]
#  [0.70600618 0.2383917  0.63265489 0.21088496]
#  [0.72712585 0.26661281 0.60593821 0.18178146]
#  [0.70558934 0.32722984 0.58287815 0.23519645]
#  [0.68307923 0.34153961 0.59769433 0.24395687]
#  [0.71486543 0.25995106 0.62202576 0.18567933]
#  [0.73122464 0.31338199 0.56873028 0.20892133]
#  [0.69595601 0.3427843  0.59208198 0.21813547]
#  [0.71529453 0.31790868 0.59607878 0.17882363]
#  [0.72785195 0.32870733 0.56349829 0.21131186]
#  [0.71171214 0.35002236 0.57170319 0.21001342]
#  [0.69594002 0.30447376 0.60894751 0.22835532]
#  [0.73089855 0.30454106 0.58877939 0.1624219 ]
#  [0.72766159 0.27533141 0.59982915 0.18683203]
#  [0.71578999 0.34430405 0.5798805  0.18121266]
#  [0.69417747 0.30370264 0.60740528 0.2386235 ]
#  [0.72366005 0.32162669 0.58582004 0.17230001]
#  [0.69385414 0.29574111 0.63698085 0.15924521]
#  [0.73154399 0.28501714 0.57953485 0.21851314]
#  [0.67017484 0.36168166 0.59571097 0.2553047 ]
#  [0.69804799 0.338117   0.59988499 0.196326  ]
#  [0.71066905 0.35533453 0.56853524 0.21320072]
#  [0.72415258 0.32534391 0.56672811 0.22039426]
#  [0.69997037 0.32386689 0.58504986 0.25073566]
#  [0.73337886 0.32948905 0.54206264 0.24445962]
#  [0.69052512 0.32145135 0.60718588 0.22620651]
#  [0.69193502 0.32561648 0.60035539 0.23403685]
#  [0.68914871 0.33943145 0.58629069 0.25714504]
#  [0.72155725 0.32308533 0.56001458 0.24769876]
#  [0.72965359 0.28954508 0.57909015 0.22005426]
#  [0.71653899 0.3307103  0.57323119 0.22047353]
#  [0.67467072 0.36998072 0.58761643 0.25028107]
#  [0.69025916 0.35097923 0.5966647  0.21058754]]
# -----------------------------------------------------------------
#
# Neural Network Implementation
#
# iteration  0 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.333333
# Iris-virginica     0.666667
# dtype: float64
#
#
# iteration  1 MSE :
#
# Iris-setosa        0.666667
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  2 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  3 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.333333
# Iris-virginica     0.666667
# dtype: float64
#
#
# iteration  4 MSE :
#
# Iris-setosa        0.666667
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  5 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.640000
# Iris-virginica     0.306667
# dtype: float64
#
#
# iteration  6 MSE :
#
# Iris-setosa        0.133333
# Iris-versicolor    0.466667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  7 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.346667
# dtype: float64
#
#
# iteration  8 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.133333
# Iris-virginica     0.126667
# dtype: float64
#
#
# iteration  9 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.326667
# Iris-virginica     0.326667
# dtype: float64
#
#
# iteration  10 MSE :
#
# Iris-setosa        0.120000
# Iris-versicolor    0.333333
# Iris-virginica     0.453333
# dtype: float64
#
#
# iteration  11 MSE :
#
# Iris-setosa        0.040000
# Iris-versicolor    0.333333
# Iris-virginica     0.293333
# dtype: float64
#
#
# iteration  12 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  13 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.326667
# Iris-virginica     0.326667
# dtype: float64
#
#
# iteration  14 MSE :
#
# Iris-setosa        0.233333
# Iris-versicolor    0.333333
# Iris-virginica     0.566667
# dtype: float64
#
#
# iteration  15 MSE :
#
# Iris-setosa        0.280000
# Iris-versicolor    0.613333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  16 MSE :
#
# Iris-setosa        0.326667
# Iris-versicolor    0.333333
# Iris-virginica     0.660000
# dtype: float64
#
#
# iteration  17 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  18 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  19 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  20 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  21 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  22 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  23 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.320000
# Iris-virginica     0.313333
# dtype: float64
#
#
# iteration  24 MSE :
#
# Iris-setosa        0.026667
# Iris-versicolor    0.333333
# Iris-virginica     0.360000
# dtype: float64
#
#
# iteration  25 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.146667
# Iris-virginica     0.140000
# dtype: float64
#
#
# iteration  26 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  27 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  28 MSE :
#
# Iris-setosa        0.020000
# Iris-versicolor    0.333333
# Iris-virginica     0.313333
# dtype: float64
#
#
# iteration  29 MSE :
#
# Iris-setosa        0.606667
# Iris-versicolor    0.333333
# Iris-virginica     0.273333
# dtype: float64
#
#
# iteration  30 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.373333
# Iris-virginica     0.040000
# dtype: float64
#
#
# iteration  31 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  32 MSE :
#
# Iris-setosa        0.020000
# Iris-versicolor    0.353333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  33 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.333333
# Iris-virginica     0.340000
# dtype: float64
#
#
# iteration  34 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.340000
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  35 MSE :
#
# Iris-setosa        0.146667
# Iris-versicolor    0.333333
# Iris-virginica     0.480000
# dtype: float64
#
#
# iteration  36 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  37 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  38 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.206667
# Iris-virginica     0.206667
# dtype: float64
#
#
# iteration  39 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  40 MSE :
#
# Iris-setosa        0.140000
# Iris-versicolor    0.473333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  41 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  42 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.053333
# Iris-virginica     0.053333
# dtype: float64
#
#
# iteration  43 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  44 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  45 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.053333
# Iris-virginica     0.053333
# dtype: float64
#
#
# iteration  46 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  47 MSE :
#
# Iris-setosa        0.020000
# Iris-versicolor    0.333333
# Iris-virginica     0.353333
# dtype: float64
#
#
# iteration  48 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.046667
# Iris-virginica     0.046667
# dtype: float64
#
#
# iteration  49 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.046667
# Iris-virginica     0.046667
# dtype: float64
#
#
# iteration  50 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  51 MSE :
#
# Iris-setosa        0.100000
# Iris-versicolor    0.333333
# Iris-virginica     0.433333
# dtype: float64
#
#
# iteration  52 MSE :
#
# Iris-setosa        0.00
# Iris-versicolor    0.32
# Iris-virginica     0.32
# dtype: float64
#
#
# iteration  53 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.333333
# Iris-virginica     0.340000
# dtype: float64
#
#
# iteration  54 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.093333
# Iris-virginica     0.093333
# dtype: float64
#
#
# iteration  55 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  56 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  57 MSE :
#
# Iris-setosa        0.040000
# Iris-versicolor    0.333333
# Iris-virginica     0.293333
# dtype: float64
#
#
# iteration  58 MSE :
#
# Iris-setosa        0.560000
# Iris-versicolor    0.333333
# Iris-virginica     0.226667
# dtype: float64
#
#
# iteration  59 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  60 MSE :
#
# Iris-setosa        0.280000
# Iris-versicolor    0.333333
# Iris-virginica     0.613333
# dtype: float64
#
#
# iteration  61 MSE :
#
# Iris-setosa        0.240000
# Iris-versicolor    0.333333
# Iris-virginica     0.093333
# dtype: float64
#
#
# iteration  62 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  63 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  64 MSE :
#
# Iris-setosa        0.293333
# Iris-versicolor    0.333333
# Iris-virginica     0.040000
# dtype: float64
#
#
# iteration  65 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  66 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  67 MSE :
#
# Iris-setosa        0.086667
# Iris-versicolor    0.333333
# Iris-virginica     0.246667
# dtype: float64
#
#
# iteration  68 MSE :
#
# Iris-setosa        0.026667
# Iris-versicolor    0.360000
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  69 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  70 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  71 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  72 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.346667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  73 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.346667
# dtype: float64
#
#
# iteration  74 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  75 MSE :
#
# Iris-setosa        0.133333
# Iris-versicolor    0.333333
# Iris-virginica     0.466667
# dtype: float64
#
#
# iteration  76 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  77 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  78 MSE :
#
# Iris-setosa        0.00
# Iris-versicolor    0.24
# Iris-virginica     0.24
# dtype: float64
#
#
# iteration  79 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  80 MSE :
#
# Iris-setosa        0.140000
# Iris-versicolor    0.473333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  81 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  82 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  83 MSE :
#
# Iris-setosa        0.320000
# Iris-versicolor    0.653333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  84 MSE :
#
# Iris-setosa        0.126667
# Iris-versicolor    0.333333
# Iris-virginica     0.206667
# dtype: float64
#
#
# iteration  85 MSE :
#
# Iris-setosa        0.193333
# Iris-versicolor    0.513333
# Iris-virginica     0.320000
# dtype: float64
#
#
# iteration  86 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.333333
# Iris-virginica     0.340000
# dtype: float64
#
#
# iteration  87 MSE :
#
# Iris-setosa        0.053333
# Iris-versicolor    0.386667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  88 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.346667
# dtype: float64
#
#
# iteration  89 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  90 MSE :
#
# Iris-setosa        0.153333
# Iris-versicolor    0.333333
# Iris-virginica     0.486667
# dtype: float64
#
#
# iteration  91 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  92 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  93 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.086667
# Iris-virginica     0.086667
# dtype: float64
#
#
# iteration  94 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  95 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  96 MSE :
#
# Iris-setosa        0.020000
# Iris-versicolor    0.333333
# Iris-virginica     0.313333
# dtype: float64
#
#
# iteration  97 MSE :
#
# Iris-setosa        0.400000
# Iris-versicolor    0.586667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  98 MSE :
#
# Iris-setosa        0.220000
# Iris-versicolor    0.333333
# Iris-virginica     0.553333
# dtype: float64
#
#
# iteration  99 MSE :
#
# Iris-setosa        0.280000
# Iris-versicolor    0.613333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  100 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.320000
# dtype: float64
#
#
# iteration  101 MSE :
#
# Iris-setosa        0.193333
# Iris-versicolor    0.526667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  102 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  103 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  104 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.346667
# dtype: float64
#
#
# iteration  105 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.346667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  106 MSE :
#
# Iris-setosa        0.080000
# Iris-versicolor    0.333333
# Iris-virginica     0.413333
# dtype: float64
#
#
# iteration  107 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  108 MSE :
#
# Iris-setosa        0.026667
# Iris-versicolor    0.333333
# Iris-virginica     0.360000
# dtype: float64
#
#
# iteration  109 MSE :
#
# Iris-setosa        0.00
# Iris-versicolor    0.28
# Iris-virginica     0.28
# dtype: float64
#
#
# iteration  110 MSE :
#
# Iris-setosa        0.020000
# Iris-versicolor    0.333333
# Iris-virginica     0.353333
# dtype: float64
#
#
# iteration  111 MSE :
#
# Iris-setosa        0.026667
# Iris-versicolor    0.360000
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  112 MSE :
#
# Iris-setosa        0.073333
# Iris-versicolor    0.333333
# Iris-virginica     0.406667
# dtype: float64
#
#
# iteration  113 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.273333
# Iris-virginica     0.273333
# dtype: float64
#
#
# iteration  114 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.333333
# Iris-virginica     0.340000
# dtype: float64
#
#
# iteration  115 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.346667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  116 MSE :
#
# Iris-setosa        0.046667
# Iris-versicolor    0.333333
# Iris-virginica     0.380000
# dtype: float64
#
#
# iteration  117 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.253333
# Iris-virginica     0.253333
# dtype: float64
#
#
# iteration  118 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.333333
# Iris-virginica     0.340000
# dtype: float64
#
#
# iteration  119 MSE :
#
# Iris-setosa        0.200000
# Iris-versicolor    0.533333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  120 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  121 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  122 MSE :
#
# Iris-setosa        0.106667
# Iris-versicolor    0.440000
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  123 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  124 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  125 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  126 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  127 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  128 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  129 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.346667
# dtype: float64
#
#
# iteration  130 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.086667
# Iris-virginica     0.086667
# dtype: float64
#
#
# iteration  131 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  132 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  133 MSE :
#
# Iris-setosa        0.020000
# Iris-versicolor    0.333333
# Iris-virginica     0.313333
# dtype: float64
#
#
# iteration  134 MSE :
#
# Iris-setosa        0.546667
# Iris-versicolor    0.446667
# Iris-virginica     0.326667
# dtype: float64
#
#
# iteration  135 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.646667
# Iris-virginica     0.313333
# dtype: float64
#
#
# iteration  136 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  137 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.333333
# Iris-virginica     0.340000
# dtype: float64
#
#
# iteration  138 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  139 MSE :
#
# Iris-setosa        0.093333
# Iris-versicolor    0.333333
# Iris-virginica     0.426667
# dtype: float64
#
#
# iteration  140 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  141 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.346667
# dtype: float64
#
#
# iteration  142 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.133333
# Iris-virginica     0.133333
# dtype: float64
#
#
# iteration  143 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  144 MSE :
#
# Iris-setosa        0.306667
# Iris-versicolor    0.640000
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  145 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  146 MSE :
#
# Iris-setosa        0.360000
# Iris-versicolor    0.360000
# Iris-virginica     0.093333
# dtype: float64
#
#
# iteration  147 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  148 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  149 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  150 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  151 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  152 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  153 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  154 MSE :
#
# Iris-setosa        0.026667
# Iris-versicolor    0.360000
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  155 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.346667
# dtype: float64
#
#
# iteration  156 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  157 MSE :
#
# Iris-setosa        0.133333
# Iris-versicolor    0.333333
# Iris-virginica     0.466667
# dtype: float64
#
#
# iteration  158 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  159 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  160 MSE :
#
# Iris-setosa        0.00
# Iris-versicolor    0.32
# Iris-virginica     0.32
# dtype: float64
#
#
# iteration  161 MSE :
#
# Iris-setosa        0.060000
# Iris-versicolor    0.333333
# Iris-virginica     0.393333
# dtype: float64
#
#
# iteration  162 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.306667
# Iris-virginica     0.306667
# dtype: float64
#
#
# iteration  163 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.346667
# dtype: float64
#
#
# iteration  164 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.266667
# Iris-virginica     0.266667
# dtype: float64
#
#
# iteration  165 MSE :
#
# Iris-setosa        0.020000
# Iris-versicolor    0.333333
# Iris-virginica     0.353333
# dtype: float64
#
#
# iteration  166 MSE :
#
# Iris-setosa        0.120000
# Iris-versicolor    0.453333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  167 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  168 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  169 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  170 MSE :
#
# Iris-setosa        0.180000
# Iris-versicolor    0.333333
# Iris-virginica     0.153333
# dtype: float64
#
#
# iteration  171 MSE :
#
# Iris-setosa        0.140000
# Iris-versicolor    0.246667
# Iris-virginica     0.106667
# dtype: float64
#
#
# iteration  172 MSE :
#
# Iris-setosa        0.186667
# Iris-versicolor    0.520000
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  173 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  174 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  175 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  176 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.066667
# Iris-virginica     0.066667
# dtype: float64
#
#
# iteration  177 MSE :
#
# Iris-setosa        0.00
# Iris-versicolor    0.22
# Iris-virginica     0.22
# dtype: float64
#
#
# iteration  178 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  179 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  180 MSE :
#
# Iris-setosa        0.026667
# Iris-versicolor    0.360000
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  181 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  182 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  183 MSE :
#
# Iris-setosa        0.093333
# Iris-versicolor    0.333333
# Iris-virginica     0.426667
# dtype: float64
#
#
# iteration  184 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  185 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.346667
# dtype: float64
#
#
# iteration  186 MSE :
#
# Iris-setosa        0.00
# Iris-versicolor    0.32
# Iris-virginica     0.32
# dtype: float64
#
#
# iteration  187 MSE :
#
# Iris-setosa        0.100000
# Iris-versicolor    0.333333
# Iris-virginica     0.433333
# dtype: float64
#
#
# iteration  188 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.326667
# Iris-virginica     0.326667
# dtype: float64
#
#
# iteration  189 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.333333
# Iris-virginica     0.340000
# dtype: float64
#
#
# iteration  190 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.093333
# Iris-virginica     0.093333
# dtype: float64
#
#
# iteration  191 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  192 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  193 MSE :
#
# Iris-setosa        0.020000
# Iris-versicolor    0.333333
# Iris-virginica     0.313333
# dtype: float64
#
#
# iteration  194 MSE :
#
# Iris-setosa        0.546667
# Iris-versicolor    0.440000
# Iris-virginica     0.320000
# dtype: float64
#
#
# iteration  195 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.613333
# Iris-virginica     0.280000
# dtype: float64
#
#
# iteration  196 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  197 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.333333
# Iris-virginica     0.340000
# dtype: float64
#
#
# iteration  198 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  199 MSE :
#
# Iris-setosa        0.133333
# Iris-versicolor    0.333333
# Iris-virginica     0.466667
# dtype: float64
#
#
# iteration  200 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  201 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  202 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.053333
# Iris-virginica     0.053333
# dtype: float64
#
#
# iteration  203 MSE :
#
# Iris-setosa        0.00
# Iris-versicolor    0.18
# Iris-virginica     0.18
# dtype: float64
#
#
# iteration  204 MSE :
#
# Iris-setosa        0.073333
# Iris-versicolor    0.406667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  205 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  206 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  207 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.333333
# Iris-virginica     0.340000
# dtype: float64
#
#
# iteration  208 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.326667
# Iris-virginica     0.326667
# dtype: float64
#
#
# iteration  209 MSE :
#
# Iris-setosa        0.100000
# Iris-versicolor    0.333333
# Iris-virginica     0.433333
# dtype: float64
#
#
# iteration  210 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.326667
# Iris-virginica     0.326667
# dtype: float64
#
#
# iteration  211 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.346667
# dtype: float64
#
#
# iteration  212 MSE :
#
# Iris-setosa        0.0
# Iris-versicolor    0.1
# Iris-virginica     0.1
# dtype: float64
#
#
# iteration  213 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  214 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  215 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.320000
# dtype: float64
#
#
# iteration  216 MSE :
#
# Iris-setosa        0.526667
# Iris-versicolor    0.433333
# Iris-virginica     0.293333
# dtype: float64
#
#
# iteration  217 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.373333
# Iris-virginica     0.040000
# dtype: float64
#
#
# iteration  218 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  219 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  220 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  221 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.346667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  222 MSE :
#
# Iris-setosa        0.020000
# Iris-versicolor    0.333333
# Iris-virginica     0.353333
# dtype: float64
#
#
# iteration  223 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  224 MSE :
#
# Iris-setosa        0.173333
# Iris-versicolor    0.333333
# Iris-virginica     0.506667
# dtype: float64
#
#
# iteration  225 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  226 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  227 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  228 MSE :
#
# Iris-setosa        0.020000
# Iris-versicolor    0.333333
# Iris-virginica     0.353333
# dtype: float64
#
#
# iteration  229 MSE :
#
# Iris-setosa        0.0
# Iris-versicolor    0.1
# Iris-virginica     0.1
# dtype: float64
#
#
# iteration  230 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  231 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  232 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.320000
# dtype: float64
#
#
# iteration  233 MSE :
#
# Iris-setosa        0.373333
# Iris-versicolor    0.613333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  234 MSE :
#
# Iris-setosa        0.273333
# Iris-versicolor    0.333333
# Iris-virginica     0.606667
# dtype: float64
#
#
# iteration  235 MSE :
#
# Iris-setosa        0.033333
# Iris-versicolor    0.366667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  236 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  237 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  238 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  239 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  240 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.333333
# Iris-virginica     0.340000
# dtype: float64
#
#
# iteration  241 MSE :
#
# Iris-setosa        0.026667
# Iris-versicolor    0.360000
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  242 MSE :
#
# Iris-setosa        0.026667
# Iris-versicolor    0.333333
# Iris-virginica     0.360000
# dtype: float64
#
#
# iteration  243 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.293333
# Iris-virginica     0.293333
# dtype: float64
#
#
# iteration  244 MSE :
#
# Iris-setosa        0.046667
# Iris-versicolor    0.333333
# Iris-virginica     0.380000
# dtype: float64
#
#
# iteration  245 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  246 MSE :
#
# Iris-setosa        0.093333
# Iris-versicolor    0.333333
# Iris-virginica     0.426667
# dtype: float64
#
#
# iteration  247 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.326667
# Iris-virginica     0.326667
# dtype: float64
#
#
# iteration  248 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.346667
# dtype: float64
#
#
# iteration  249 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.133333
# Iris-virginica     0.133333
# dtype: float64
#
#
# iteration  250 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  251 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  252 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  253 MSE :
#
# Iris-setosa        0.446667
# Iris-versicolor    0.333333
# Iris-virginica     0.113333
# dtype: float64
#
#
# iteration  254 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  255 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  256 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  257 MSE :
#
# Iris-setosa        0.113333
# Iris-versicolor    0.446667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  258 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  259 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  260 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  261 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  262 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  263 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  264 MSE :
#
# Iris-setosa        0.060000
# Iris-versicolor    0.333333
# Iris-virginica     0.393333
# dtype: float64
#
#
# iteration  265 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.313333
# Iris-virginica     0.313333
# dtype: float64
#
#
# iteration  266 MSE :
#
# Iris-setosa        0.020000
# Iris-versicolor    0.333333
# Iris-virginica     0.353333
# dtype: float64
#
#
# iteration  267 MSE :
#
# Iris-setosa        0.0
# Iris-versicolor    0.2
# Iris-virginica     0.2
# dtype: float64
#
#
# iteration  268 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  269 MSE :
#
# Iris-setosa        0.300000
# Iris-versicolor    0.633333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  270 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  271 MSE :
#
# Iris-setosa        0.233333
# Iris-versicolor    0.333333
# Iris-virginica     0.100000
# dtype: float64
#
#
# iteration  272 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  273 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  274 MSE :
#
# Iris-setosa        0.320000
# Iris-versicolor    0.333333
# Iris-virginica     0.026667
# dtype: float64
#
#
# iteration  275 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  276 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  277 MSE :
#
# Iris-setosa        0.100000
# Iris-versicolor    0.333333
# Iris-virginica     0.233333
# dtype: float64
#
#
# iteration  278 MSE :
#
# Iris-setosa        0.093333
# Iris-versicolor    0.426667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  279 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  280 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  281 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  282 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  283 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.333333
# Iris-virginica     0.340000
# dtype: float64
#
#
# iteration  284 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  285 MSE :
#
# Iris-setosa        0.133333
# Iris-versicolor    0.333333
# Iris-virginica     0.466667
# dtype: float64
#
#
# iteration  286 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  287 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  288 MSE :
#
# Iris-setosa        0.00
# Iris-versicolor    0.24
# Iris-virginica     0.24
# dtype: float64
#
#
# iteration  289 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  290 MSE :
#
# Iris-setosa        0.053333
# Iris-versicolor    0.386667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  291 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.346667
# dtype: float64
#
#
# iteration  292 MSE :
#
# Iris-setosa        0.00
# Iris-versicolor    0.24
# Iris-virginica     0.24
# dtype: float64
#
#
# iteration  293 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.333333
# Iris-virginica     0.340000
# dtype: float64
#
#
# iteration  294 MSE :
#
# Iris-setosa        0.113333
# Iris-versicolor    0.446667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  295 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  296 MSE :
#
# Iris-setosa        0.00
# Iris-versicolor    0.18
# Iris-virginica     0.18
# dtype: float64
#
#
# iteration  297 MSE :
#
# Iris-setosa        0.053333
# Iris-versicolor    0.386667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  298 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  299 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  300 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.333333
# Iris-virginica     0.340000
# dtype: float64
#
#
# iteration  301 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  302 MSE :
#
# Iris-setosa        0.146667
# Iris-versicolor    0.333333
# Iris-virginica     0.480000
# dtype: float64
#
#
# iteration  303 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  304 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  305 MSE :
#
# Iris-setosa        0.00
# Iris-versicolor    0.14
# Iris-virginica     0.14
# dtype: float64
#
#
# iteration  306 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  307 MSE :
#
# Iris-setosa        0.320000
# Iris-versicolor    0.653333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  308 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  309 MSE :
#
# Iris-setosa        0.546667
# Iris-versicolor    0.333333
# Iris-virginica     0.213333
# dtype: float64
#
#
# iteration  310 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  311 MSE :
#
# Iris-setosa        0.146667
# Iris-versicolor    0.333333
# Iris-virginica     0.480000
# dtype: float64
#
#
# iteration  312 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  313 MSE :
#
# Iris-setosa        0.020000
# Iris-versicolor    0.353333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  314 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  315 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  316 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  317 MSE :
#
# Iris-setosa        0.020000
# Iris-versicolor    0.353333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  318 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.333333
# Iris-virginica     0.340000
# dtype: float64
#
#
# iteration  319 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  320 MSE :
#
# Iris-setosa        0.093333
# Iris-versicolor    0.333333
# Iris-virginica     0.426667
# dtype: float64
#
#
# iteration  321 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  322 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.346667
# dtype: float64
#
#
# iteration  323 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.273333
# Iris-virginica     0.273333
# dtype: float64
#
#
# iteration  324 MSE :
#
# Iris-setosa        0.020000
# Iris-versicolor    0.333333
# Iris-virginica     0.353333
# dtype: float64
#
#
# iteration  325 MSE :
#
# Iris-setosa        0.066667
# Iris-versicolor    0.400000
# Iris-virginica     0.333333
# dtype: float64
#
#
# ...
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  374 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  375 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.346667
# dtype: float64
#
#
# iteration  376 MSE :
#
# Iris-setosa        0.00
# Iris-versicolor    0.04
# Iris-virginica     0.04
# dtype: float64
#
#
# iteration  377 MSE :
#
# Iris-setosa        0.00
# Iris-versicolor    0.24
# Iris-virginica     0.24
# dtype: float64
#
#
# iteration  378 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.333333
# Iris-virginica     0.340000
# dtype: float64
#
#
# iteration  379 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.346667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  380 MSE :
#
# Iris-setosa        0.080000
# Iris-versicolor    0.333333
# Iris-virginica     0.413333
# dtype: float64
#
#
# iteration  381 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  382 MSE :
#
# Iris-setosa        0.020000
# Iris-versicolor    0.333333
# Iris-virginica     0.353333
# dtype: float64
#
#
# iteration  383 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.286667
# Iris-virginica     0.286667
# dtype: float64
#
#
# iteration  384 MSE :
#
# Iris-setosa        0.046667
# Iris-versicolor    0.333333
# Iris-virginica     0.380000
# dtype: float64
#
#
# iteration  385 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  386 MSE :
#
# Iris-setosa        0.093333
# Iris-versicolor    0.333333
# Iris-virginica     0.426667
# dtype: float64
#
#
# iteration  387 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  388 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.346667
# dtype: float64
#
#
# iteration  389 MSE :
#
# Iris-setosa        0.00
# Iris-versicolor    0.08
# Iris-virginica     0.08
# dtype: float64
#
#
# iteration  390 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  391 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  392 MSE :
#
# Iris-setosa        0.026667
# Iris-versicolor    0.333333
# Iris-virginica     0.306667
# dtype: float64
#
#
# iteration  393 MSE :
#
# Iris-setosa        0.373333
# Iris-versicolor    0.613333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  394 MSE :
#
# Iris-setosa        0.280000
# Iris-versicolor    0.333333
# Iris-virginica     0.613333
# dtype: float64
#
#
# iteration  395 MSE :
#
# Iris-setosa        0.060000
# Iris-versicolor    0.393333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  396 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  397 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  398 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  399 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  400 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  401 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  402 MSE :
#
# Iris-setosa        0.026667
# Iris-versicolor    0.333333
# Iris-virginica     0.360000
# dtype: float64
#
#
# iteration  403 MSE :
#
# Iris-setosa        0.00
# Iris-versicolor    0.32
# Iris-virginica     0.32
# dtype: float64
#
#
# iteration  404 MSE :
#
# Iris-setosa        0.100000
# Iris-versicolor    0.333333
# Iris-virginica     0.433333
# dtype: float64
#
#
# iteration  405 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.326667
# Iris-virginica     0.326667
# dtype: float64
#
#
# iteration  406 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.333333
# Iris-virginica     0.340000
# dtype: float64
#
#
# iteration  407 MSE :
#
# Iris-setosa        0.00
# Iris-versicolor    0.12
# Iris-virginica     0.12
# dtype: float64
#
#
# iteration  408 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  409 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  410 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  411 MSE :
#
# Iris-setosa        0.506667
# Iris-versicolor    0.333333
# Iris-virginica     0.173333
# dtype: float64
#
#
# iteration  412 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  413 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.346667
# dtype: float64
#
#
# iteration  414 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  415 MSE :
#
# Iris-setosa        0.266667
# Iris-versicolor    0.600000
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  416 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  417 MSE :
#
# Iris-setosa        0.193333
# Iris-versicolor    0.526667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  418 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  419 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.346667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  420 MSE :
#
# Iris-setosa        0.026667
# Iris-versicolor    0.333333
# Iris-virginica     0.360000
# dtype: float64
#
#
# iteration  421 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  422 MSE :
#
# Iris-setosa        0.146667
# Iris-versicolor    0.333333
# Iris-virginica     0.480000
# dtype: float64
#
#
# iteration  423 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  424 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  425 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.326667
# Iris-virginica     0.326667
# dtype: float64
#
#
# iteration  426 MSE :
#
# Iris-setosa        0.033333
# Iris-versicolor    0.333333
# Iris-virginica     0.366667
# dtype: float64
#
#
# iteration  427 MSE :
#
# Iris-setosa        0.00
# Iris-versicolor    0.14
# Iris-virginica     0.14
# dtype: float64
#
#
# iteration  428 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  429 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  430 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  431 MSE :
#
# Iris-setosa        0.380000
# Iris-versicolor    0.333333
# Iris-virginica     0.060000
# dtype: float64
#
#
# iteration  432 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  433 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  434 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.320000
# dtype: float64
#
#
# iteration  435 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.346667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  436 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  437 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.346667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  438 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  439 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  440 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.333333
# Iris-virginica     0.340000
# dtype: float64
#
#
# iteration  441 MSE :
#
# Iris-setosa        0.033333
# Iris-versicolor    0.366667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  442 MSE :
#
# Iris-setosa        0.046667
# Iris-versicolor    0.333333
# Iris-virginica     0.380000
# dtype: float64
#
#
# iteration  443 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  444 MSE :
#
# Iris-setosa        0.093333
# Iris-versicolor    0.333333
# Iris-virginica     0.426667
# dtype: float64
#
#
# iteration  445 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.326667
# Iris-virginica     0.326667
# dtype: float64
#
#
# iteration  446 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.346667
# dtype: float64
#
#
# iteration  447 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.086667
# Iris-virginica     0.086667
# dtype: float64
#
#
# iteration  448 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  449 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  450 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.320000
# dtype: float64
#
#
# iteration  451 MSE :
#
# Iris-setosa        0.440000
# Iris-versicolor    0.560000
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  452 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.440000
# Iris-virginica     0.560000
# dtype: float64
#
#
# iteration  453 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  454 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  455 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  456 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  457 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.346667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  458 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.333333
# Iris-virginica     0.340000
# dtype: float64
#
#
# iteration  459 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.346667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  460 MSE :
#
# Iris-setosa        0.093333
# Iris-versicolor    0.333333
# Iris-virginica     0.426667
# dtype: float64
#
#
# iteration  461 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  462 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.346667
# dtype: float64
#
#
# iteration  463 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.093333
# Iris-virginica     0.093333
# dtype: float64
#
#
# iteration  464 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  465 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  466 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  467 MSE :
#
# Iris-setosa        0.406667
# Iris-versicolor    0.573333
# Iris-virginica     0.326667
# dtype: float64
#
#
# iteration  468 MSE :
#
# Iris-setosa        0.293333
# Iris-versicolor    0.333333
# Iris-virginica     0.626667
# dtype: float64
#
#
# iteration  469 MSE :
#
# Iris-setosa        0.113333
# Iris-versicolor    0.446667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  470 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  471 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  472 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  473 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  474 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  475 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  476 MSE :
#
# Iris-setosa        0.006667
# Iris-versicolor    0.333333
# Iris-virginica     0.340000
# dtype: float64
#
#
# iteration  477 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.233333
# Iris-virginica     0.233333
# dtype: float64
#
#
# iteration  478 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  479 MSE :
#
# Iris-setosa        0.146667
# Iris-versicolor    0.480000
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  480 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  481 MSE :
#
# Iris-setosa        0.0
# Iris-versicolor    0.3
# Iris-virginica     0.3
# dtype: float64
#
#
# iteration  482 MSE :
#
# Iris-setosa        0.280000
# Iris-versicolor    0.613333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  483 MSE :
#
# Iris-setosa        0.046667
# Iris-versicolor    0.333333
# Iris-virginica     0.286667
# dtype: float64
#
#
# iteration  484 MSE :
#
# Iris-setosa        0.286667
# Iris-versicolor    0.620000
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  485 MSE :
#
# Iris-setosa        0.020000
# Iris-versicolor    0.333333
# Iris-virginica     0.353333
# dtype: float64
#
#
# iteration  486 MSE :
#
# Iris-setosa        0.333333
# Iris-versicolor    0.666667
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  487 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  488 MSE :
#
# Iris-setosa        0.200000
# Iris-versicolor    0.333333
# Iris-virginica     0.133333
# dtype: float64
#
#
# iteration  489 MSE :
#
# Iris-setosa        0.300000
# Iris-versicolor    0.633333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  490 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  491 MSE :
#
# Iris-setosa        0.220000
# Iris-versicolor    0.553333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  492 MSE :
#
# Iris-setosa        0.013333
# Iris-versicolor    0.333333
# Iris-virginica     0.346667
# dtype: float64
#
#
# iteration  493 MSE :
#
# Iris-setosa        0.026667
# Iris-versicolor    0.360000
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  494 MSE :
#
# Iris-setosa        0.073333
# Iris-versicolor    0.333333
# Iris-virginica     0.406667
# dtype: float64
#
#
# iteration  495 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  496 MSE :
#
# Iris-setosa        0.033333
# Iris-versicolor    0.333333
# Iris-virginica     0.366667
# dtype: float64
#
#
# iteration  497 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
# iteration  498 MSE :
#
# Iris-setosa        0.133333
# Iris-versicolor    0.333333
# Iris-virginica     0.466667
# dtype: float64
#
#
# iteration  499 MSE :
#
# Iris-setosa        0.000000
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# dtype: float64
#
#
#
#
# -----------------------------------------------------------------
#
# Final Prediction of Neural Network
#
# Clustered values :
# 	 Iris-sentosa : 50
# 	 Iris-versicolor : 96
# 	 Iris-virginica : 4
#
#
#
#
# -----------------------------------------------------------------
#
# Purity Clustering of the Final Prediction of Neural Network
#
# [[254  46]
#  [ 46 104]]
# purity score of CNN Iris clustering :  0.7955555555555556

# %%
#removing bias
import numpy as np
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns


# Assign the csv data to a DataFrame
iris_data = pd.read_csv("/content/sample_data/Iris (1).csv")

#class labels
labels = ["Iris-sentosa","Iris-versicolor","Iris-virginica"]

# Print the first 10 instances
iris_data.head(10).style

# Information on the dataset
iris_data.info()

# Encoding labels using hot encoding approch
def target_hotencoding(target):
    encoded_target = pd.DataFrame()
    for label in target.unique():
        encoded_target[label] = np.where(target == label, 1, 0)
    return encoded_target




# Total Instances on each iris plant class
print(iris_data["Species"].value_counts())

# Dimensions of the dataset
iris_data.shape

#input data and the target
X=iris_data.iloc[0:,1:5]
y=iris_data.iloc[0:,5] 




# normalize the train data attributes
normalized_X = preprocessing.normalize(X)
#normalized_X

#hot encode of the output
target = target_hotencoding(y)
#print(y)

#---------------------------------------------------------------------------------------#
                        
                             #implementing neural network

#generating weights randomly
np.random.seed(5)
W = np.random.rand(4,3)

#generating bias randomly
bias = np.random.rand(3,1)

#learning rate
lr = 0.05

print("\n")

#printing the random weights
#print("randomly generated weights \n",weights)

print("\n")

# normalize the randomly generated weights
weights = preprocessing.normalize(W)

#print("randomly generated bias \n",bias)
#print("SHAPE OF weights :", normalized_weights.shape)


#weighted sum of hidden layer node or output layer node
#activation function to get the output (sigmoid)

#activation function
def sigmoid(x):
    return 1/(1+np.exp(-x))

#finding the deriviative of the value returning from sigmoid function
def sigmoid_der(x):
    return x*(1-x)

m = target.shape[1]

#feed forward and backpropagration
for iteration in range(500):
    inputs = normalized_X


   # feedforward step 1- calculating the weighted sum
    #XW = (np.dot(normalized_X, weights) + (bias.T))
    XW = (np.dot(normalized_X, weights))

   #feedforward step 2 - passing the weighted output to sigmiod 
    z = sigmoid(XW)
    output = np.zeros_like(z)
    output[np.arange(len(z)), z.argmax(1)] = 1

    # Casting float values to int
    output = output.astype(int)
    
    #print(output)


   #calculating the mean squared error
    MSE = np.mean(np.square(target-output))
    print(iteration, " : ")
    print("ERROR = \n",MSE)
    
    # backpropagation step 1
    error_of_output = output - (target)

    #applying chain rule of differentiation
    #dcost :derivation of cost function with respect to weight
    #dcost_dpred : derivation of cost function with respect to sigmoid function
    

    # backpropagation step 2
    dcost_dpred = error_of_output

    #n12 = np.squeeze(np.asarray(z))
    dpred_dz = sigmoid_der(z)

    z_delta = dcost_dpred * dpred_dz

    #inputs_weights = normalized_X
    #directly multiplying the transpose of input matrix with corresponding z_delta
    inputs = normalized_X.T
    
    #multiplying by lr to increase the speed of convergence
    weights = weights - (lr * np.dot(inputs, z_delta))
    
    db2 = (1 / m) * np.sum(error_of_output, axis = 1) 
    print("db2 :",db2)

    bias = bias - (lr*db2)
    print(bias)
    #for num in z_delta:
      #bias = bias - (lr * num)

    weights = preprocessing.normalize(weights)

    #bias = bias - (lr * np.dot(bias, 1))
    #print(bias)




#plt.plot(error_of_output)
#plt.show()

final_prediction  = sigmoid(np.dot(normalized_X, weights))

prediction = np.zeros_like(final_prediction)

prediction[np.arange(len(final_prediction)), final_prediction.argmax(1)] = 1
prediction = prediction.astype(int)


prediction = pd.DataFrame(prediction, columns=labels)
print(f"Clustered values :")
for cluster in prediction.columns:  print(f"\t{cluster} : {prediction[cluster].sum()}")

 #-----------------------------------------------------------------------------------------------#
#purity clustering
import numpy as np
from sklearn import metrics
from scipy.optimize import linear_sum_assignment

def cluster_accuracy(y_true, y_pred):
    # compute contingency matrix (also called confusion matrix)
    contingency_matrix = metrics.cluster.contingency_matrix(y_true, y_pred)
    print(contingency_matrix)

    # Find optimal one-to-one mapping between cluster labels and true labels
    row_ind, col_ind = linear_sum_assignment(-contingency_matrix)

    # Return cluster accuracy
    return contingency_matrix[row_ind, col_ind].sum() / np.sum(contingency_matrix)


print(cluster_accuracy(target,prediction))
